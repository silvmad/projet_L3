# %%
import torch
from transformers import CamembertTokenizer, CamembertModel, CamembertForSequenceClassification, Trainer, TrainingArguments, AutoModel
from sklearn.ensemble import IsolationForest
import numpy as np
from sklearn.decomposition import PCA
from clustertools import *

# %%
datasets = ["africain", "antisemite", "arabe", "asie", "capacitiste", "chretiens", "gitan", "lgbt", "miso", "musulman"]
cluster_dir = "clusters/{}/"
datasets_dir = "datasets/{}.txt"

# %% [markdown]
# ### Récupération des tweets

# %%
def load_msg(raw_dataset_file):
    with open(raw_dataset_file, "r") as file:
        raw_dataset = file.read().splitlines()
    return raw_dataset

# %% [markdown]
# ### Encodage du jeu de données
#
# On charge le modèle depuis le disque

# %%
model_dir = "models/tweetbert"
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
tokenizer = CamembertTokenizer.from_pretrained(model_dir, do_lowercase=False)
camembert = CamembertModel.from_pretrained(model_dir)
# Out:
# Some weights of the model checkpoint at models/tweetbert were not used when initializing CamembertModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing CamembertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CamembertModel were not initialized from the model checkpoint at models/tweetbert and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
r = camembert.to(device)

# %%
def encode(sample):
    encoded = []
    for n in range(0, len(sample), 50):
        batch = tokenizer(sample[n:n+50], padding=True, truncation=True, max_length=512, return_tensors="pt")
        torch.cuda.empty_cache()
        batch.to(device)
        with torch.no_grad():
            outp = camembert(**batch)
        encoded.append(outp['last_hidden_state'][:,0,:].to('cpu'))
    return torch.cat(encoded)

# %% [markdown]
# ### Utilisation de l'algorithme Isolation Forest sur tous les clusters pour supprimer les outliers
# On sauvegarde les clusters débarassés de leurs outliers

# %%
# %%time

for dataset in datasets:
    print("Dataset {}.".format(dataset))
    cd = cluster_dir.format(dataset)
    new_cd = cluster_dir.format(dataset + "_post_IF")
    if not os.path.exists(cd): 
        os.mkdir(cd)
    if not os.path.exists(new_cd): 
        os.mkdir(new_cd)
    dir_it = os.scandir(path=cd)
    filenames = [entry.name for entry in dir_it] 
    filenames.remove("info.txt")
    for filename in filenames:
        print("Cluster {}".format(filename))
        msg = load_msg(cd + filename)
        msg_encoded = encode(msg)
        if_model = IsolationForest(n_jobs=-1, random_state=42, contamination=0.15)
        if_model.fit(msg_encoded)
        pred = if_model.predict(msg_encoded)
        cluster_post_IF = []
        for p, m in zip(pred, msg):
            if (p == 1):
                cluster_post_IF.append(m)
        save_cluster_raw_msg(cluster_post_IF, new_cd + filename)
# Out:
# Dataset africain.
# Cluster cluster42_haineux.txt
# Cluster cluster0_haineux.txt
# Cluster cluster10_haineux.txt
# Cluster cluster11_haineux.txt
# Cluster cluster13_haineux.txt
# Cluster cluster15_haineux.txt
# Cluster cluster16_haineux.txt
# Cluster cluster21_normal.txt
# Cluster cluster23_haineux.txt
# Cluster cluster25_haineux.txt
# Cluster cluster31_normal.txt
# Cluster cluster33_normal.txt
# Cluster cluster38_haineux.txt
# Cluster cluster39_haineux.txt
# Cluster cluster3_haineux.txt
# Cluster cluster40_haineux.txt
# Cluster cluster44_normal.txt
# Cluster cluster49_haineux.txt
# Cluster cluster4_haineux.txt
# Cluster cluster54_normal.txt
# Cluster cluster55_normal.txt
# Cluster cluster56_normal.txt
# Cluster cluster59_haineux.txt
# Cluster cluster60_normal.txt
# Cluster cluster69_haineux.txt
# Cluster cluster6_haineux.txt
# Cluster cluster70_normal.txt
# Cluster cluster71_normal.txt
# Cluster cluster74_normal.txt
# Cluster cluster76_normal.txt
# Cluster cluster77_normal.txt
# Cluster cluster81_haineux.txt
# Cluster cluster85_normal.txt
# Cluster cluster87_normal.txt
# Cluster cluster92_normal.txt
# Cluster cluster93_haineux.txt
# Cluster cluster97_normal.txt
# Cluster cluster98_normal.txt
# Dataset antisemite.
# Cluster cluster44_haineux.txt
# Cluster cluster69_haineux.txt
# Cluster cluster0_normal.txt
# Cluster cluster14_haineux.txt
# Cluster cluster15_haineux.txt
# Cluster cluster16_haineux.txt
# Cluster cluster18_haineux.txt
# Cluster cluster19_normal.txt
# Cluster cluster24_haineux.txt
# Cluster cluster25_haineux.txt
# Cluster cluster26_haineux.txt
# Cluster cluster27_haineux.txt
# Cluster cluster33_haineux.txt
# Cluster cluster34_haineux.txt
# Cluster cluster35_haineux.txt
# Cluster cluster36_haineux.txt
# Cluster cluster37_haineux.txt
# Cluster cluster46_haineux.txt
# Cluster cluster47_haineux.txt
# Cluster cluster48_haineux.txt
# Cluster cluster49_haineux.txt
# Cluster cluster4_haineux.txt
# Cluster cluster53_haineux.txt
# Cluster cluster54_haineux.txt
# Cluster cluster55_haineux.txt
# Cluster cluster56_haineux.txt
# Cluster cluster57_haineux.txt
# Cluster cluster58_haineux.txt
# Cluster cluster59_haineux.txt
# Cluster cluster5_haineux.txt
# Cluster cluster67_haineux.txt
# Cluster cluster68_haineux.txt
# Cluster cluster6_haineux.txt
# Cluster cluster70_normal.txt
# Cluster cluster72_haineux.txt
# Cluster cluster74_haineux.txt
# Cluster cluster77_haineux.txt
# Cluster cluster79_haineux.txt
# Cluster cluster81_haineux.txt
# Cluster cluster84_haineux.txt
# Cluster cluster85_haineux.txt
# Cluster cluster86_haineux.txt
# Cluster cluster87_haineux.txt
# Cluster cluster88_haineux.txt
# Cluster cluster89_haineux.txt
# Cluster cluster8_haineux.txt
# Cluster cluster90_haineux.txt
# Cluster cluster91_haineux.txt
# Cluster cluster92_haineux.txt
# Cluster cluster95_haineux.txt
# Cluster cluster96_haineux.txt
# Cluster cluster97_haineux.txt
# Cluster cluster9_haineux.txt
# Dataset arabe.
# Cluster cluster65_haineux.txt
# Cluster cluster20_normal.txt
# Cluster cluster24_haineux.txt
# Cluster cluster25_normal.txt
# Cluster cluster32_normal.txt
# Cluster cluster33_normal.txt
# Cluster cluster38_haineux.txt
# Cluster cluster40_haineux.txt
# Cluster cluster48_haineux.txt
# Cluster cluster49_haineux.txt
# Cluster cluster56_haineux.txt
# Cluster cluster58_haineux.txt
# Cluster cluster59_haineux.txt
# Cluster cluster60_haineux.txt
# Cluster cluster62_haineux.txt
# Cluster cluster63_haineux.txt
# Cluster cluster66_haineux.txt
# Cluster cluster67_haineux.txt
# Cluster cluster68_haineux.txt
# Cluster cluster69_haineux.txt
# Cluster cluster76_haineux.txt
# Cluster cluster77_haineux.txt
# Cluster cluster78_haineux.txt
# Cluster cluster79_haineux.txt
# Cluster cluster80_haineux.txt
# Cluster cluster82_haineux.txt
# Cluster cluster83_haineux.txt
# Cluster cluster86_haineux.txt
# Cluster cluster87_haineux.txt
# Cluster cluster88_haineux.txt
# Cluster cluster89_haineux.txt
# Cluster cluster91_haineux.txt
# Cluster cluster92_haineux.txt
# Cluster cluster93_haineux.txt
# Cluster cluster96_haineux.txt
# Cluster cluster97_haineux.txt
# Cluster cluster98_haineux.txt
# Cluster cluster99_haineux.txt
# Cluster cluster9_haineux.txt
# Dataset asie.
# Cluster cluster2_normal.txt
# Cluster cluster58_normal.txt
# Cluster cluster10_normal.txt
# Cluster cluster11_normal.txt
# Cluster cluster12_normal.txt
# Cluster cluster13_normal.txt
# Cluster cluster14_normal.txt
# Cluster cluster15_normal.txt
# Cluster cluster16_haineux.txt
# Cluster cluster17_haineux.txt
# Cluster cluster18_normal.txt
# Cluster cluster19_normal.txt
# Cluster cluster1_normal.txt
# Cluster cluster20_normal.txt
# Cluster cluster21_normal.txt
# Cluster cluster22_normal.txt
# Cluster cluster23_normal.txt
# Cluster cluster28_normal.txt
# Cluster cluster30_normal.txt
# Cluster cluster34_normal.txt
# Cluster cluster35_normal.txt
# Cluster cluster36_normal.txt
# Cluster cluster3_normal.txt
# Cluster cluster41_normal.txt
# Cluster cluster42_normal.txt
# Cluster cluster44_haineux.txt
# Cluster cluster46_normal.txt
# Cluster cluster48_normal.txt
# Cluster cluster49_normal.txt
# Cluster cluster4_normal.txt
# Cluster cluster50_normal.txt
# Cluster cluster52_haineux.txt
# Cluster cluster54_haineux.txt
# Cluster cluster59_normal.txt
# Cluster cluster60_normal.txt
# Cluster cluster61_normal.txt
# Cluster cluster62_normal.txt
# Cluster cluster63_normal.txt
# Cluster cluster66_normal.txt
# Cluster cluster69_normal.txt
# Cluster cluster6_normal.txt
# Cluster cluster72_normal.txt
# Cluster cluster73_normal.txt
# Cluster cluster76_normal.txt
# Cluster cluster77_normal.txt
# Cluster cluster78_normal.txt
# Cluster cluster7_normal.txt
# Cluster cluster80_normal.txt
# Cluster cluster83_normal.txt
# Cluster cluster84_normal.txt
# Cluster cluster85_normal.txt
# Cluster cluster86_normal.txt
# Cluster cluster8_normal.txt
# Cluster cluster90_normal.txt
# Cluster cluster91_normal.txt
# Cluster cluster92_normal.txt
# Cluster cluster93_normal.txt
# Cluster cluster94_normal.txt
# Cluster cluster95_normal.txt
# Cluster cluster96_normal.txt
# Cluster cluster97_normal.txt
# Cluster cluster9_normal.txt
# Dataset capacitiste.
# Cluster cluster0_haineux.txt
# Cluster cluster13_haineux.txt
# Cluster cluster14_haineux.txt
# Cluster cluster15_haineux.txt
# Cluster cluster16_haineux.txt
# Cluster cluster18_haineux.txt
# Cluster cluster1_haineux.txt
# Cluster cluster21_haineux.txt
# Cluster cluster22_haineux.txt
# Cluster cluster23_haineux.txt
# Cluster cluster24_haineux.txt
# Cluster cluster25_haineux.txt
# Cluster cluster26_haineux.txt
# Cluster cluster28_haineux.txt
# Cluster cluster30_haineux.txt
# Cluster cluster34_haineux.txt
# Cluster cluster35_haineux.txt
# Cluster cluster36_haineux.txt
# Cluster cluster37_haineux.txt
# Cluster cluster38_haineux.txt
# Cluster cluster39_haineux.txt
# Cluster cluster3_haineux.txt
# Cluster cluster41_haineux.txt
# Cluster cluster42_haineux.txt
# Cluster cluster45_haineux.txt
# Cluster cluster46_haineux.txt
# Cluster cluster49_haineux.txt
# Cluster cluster4_haineux.txt
# Cluster cluster50_haineux.txt
# Cluster cluster51_haineux.txt
# Cluster cluster54_haineux.txt
# Cluster cluster56_haineux.txt
# Cluster cluster57_haineux.txt
# Cluster cluster59_normal.txt
# Cluster cluster5_haineux.txt
# Cluster cluster60_haineux.txt
# Cluster cluster61_haineux.txt
# Cluster cluster64_haineux.txt
# Cluster cluster65_haineux.txt
# Cluster cluster67_haineux.txt
# Cluster cluster69_haineux.txt
# Cluster cluster6_haineux.txt
# Cluster cluster70_haineux.txt
# Cluster cluster71_haineux.txt
# Cluster cluster72_haineux.txt
# Cluster cluster75_haineux.txt
# Cluster cluster79_haineux.txt
# Cluster cluster80_haineux.txt
# Cluster cluster81_haineux.txt
# Cluster cluster82_haineux.txt
# Cluster cluster83_normal.txt
# Cluster cluster84_haineux.txt
# Cluster cluster85_haineux.txt
# Cluster cluster89_haineux.txt
# Cluster cluster90_haineux.txt
# Cluster cluster91_haineux.txt
# Cluster cluster93_haineux.txt
# Cluster cluster94_haineux.txt
# Cluster cluster95_haineux.txt
# Cluster cluster96_normal.txt
# Cluster cluster98_haineux.txt
# Cluster cluster33_haineux.txt
# Cluster cluster52_haineux.txt
# Cluster cluster73_haineux.txt
# Dataset chretiens.
# Cluster cluster51_normal.txt
# Cluster cluster11_normal.txt
# Cluster cluster14_haineux.txt
# Cluster cluster16_haineux.txt
# Cluster cluster17_haineux.txt
# Cluster cluster22_haineux.txt
# Cluster cluster26_haineux.txt
# Cluster cluster28_haineux.txt
# Cluster cluster2_haineux.txt
# Cluster cluster30_normal.txt
# Cluster cluster32_normal.txt
# Cluster cluster37_haineux.txt
# Cluster cluster38_haineux.txt
# Cluster cluster40_normal.txt
# Cluster cluster41_normal.txt
# Cluster cluster4_haineux.txt
# Cluster cluster52_normal.txt
# Cluster cluster56_normal.txt
# Cluster cluster5_normal.txt
# Cluster cluster61_normal.txt
# Cluster cluster63_normal.txt
# Cluster cluster64_normal.txt
# Cluster cluster66_normal.txt
# Cluster cluster67_normal.txt
# Cluster cluster6_haineux.txt
# Cluster cluster72_normal.txt
# Cluster cluster73_normal.txt
# Cluster cluster74_normal.txt
# Cluster cluster76_normal.txt
# Cluster cluster80_normal.txt
# Cluster cluster83_normal.txt
# Cluster cluster84_normal.txt
# Cluster cluster92_normal.txt
# Cluster cluster93_haineux.txt
# Cluster cluster94_normal.txt
# Cluster cluster95_normal.txt
# Cluster cluster98_normal.txt
# Cluster cluster99_normal.txt
# Dataset gitan.
# Cluster cluster38_haineux.txt
# Cluster cluster12_normal.txt
# Cluster cluster14_normal.txt
# Cluster cluster22_normal.txt
# Cluster cluster23_haineux.txt
# Cluster cluster24_normal.txt
# Cluster cluster25_normal.txt
# Cluster cluster26_normal.txt
# Cluster cluster27_haineux.txt
# Cluster cluster2_normal.txt
# Cluster cluster31_normal.txt
# Cluster cluster32_normal.txt
# Cluster cluster33_normal.txt
# Cluster cluster34_normal.txt
# Cluster cluster35_haineux.txt
# Cluster cluster37_normal.txt
# Cluster cluster3_normal.txt
# Cluster cluster40_normal.txt
# Cluster cluster42_normal.txt
# Cluster cluster43_normal.txt
# Cluster cluster46_haineux.txt
# Cluster cluster47_haineux.txt
# Cluster cluster48_normal.txt
# Cluster cluster4_normal.txt
# Cluster cluster50_normal.txt
# Cluster cluster51_normal.txt
# Cluster cluster52_normal.txt
# Cluster cluster53_normal.txt
# Cluster cluster55_haineux.txt
# Cluster cluster56_haineux.txt
# Cluster cluster59_haineux.txt
# Cluster cluster60_normal.txt
# Cluster cluster61_normal.txt
# Cluster cluster64_haineux.txt
# Cluster cluster65_haineux.txt
# Cluster cluster66_haineux.txt
# Cluster cluster68_normal.txt
# Cluster cluster70_normal.txt
# Cluster cluster72_normal.txt
# Cluster cluster75_haineux.txt
# Cluster cluster76_haineux.txt
# Cluster cluster80_normal.txt
# Cluster cluster85_haineux.txt
# Cluster cluster89_normal.txt
# Cluster cluster90_normal.txt
# Dataset lgbt.
# Cluster cluster41_haineux.txt
# Cluster cluster62_haineux.txt
# Cluster cluster15_haineux.txt
# Cluster cluster16_haineux.txt
# Cluster cluster17_haineux.txt
# Cluster cluster21_haineux.txt
# Cluster cluster23_normal.txt
# Cluster cluster26_haineux.txt
# Cluster cluster27_haineux.txt
# Cluster cluster28_haineux.txt
# Cluster cluster32_haineux.txt
# Cluster cluster33_normal.txt
# Cluster cluster34_haineux.txt
# Cluster cluster36_haineux.txt
# Cluster cluster37_haineux.txt
# Cluster cluster38_haineux.txt
# Cluster cluster39_haineux.txt
# Cluster cluster42_haineux.txt
# Cluster cluster44_haineux.txt
# Cluster cluster46_haineux.txt
# Cluster cluster47_haineux.txt
# Cluster cluster48_haineux.txt
# Cluster cluster49_haineux.txt
# Cluster cluster52_haineux.txt
# Cluster cluster53_haineux.txt
# Cluster cluster54_haineux.txt
# Cluster cluster56_haineux.txt
# Cluster cluster57_haineux.txt
# Cluster cluster58_haineux.txt
# Cluster cluster59_haineux.txt
# Cluster cluster60_normal.txt
# Cluster cluster61_haineux.txt
# Cluster cluster64_haineux.txt
# Cluster cluster65_haineux.txt
# Cluster cluster66_haineux.txt
# Cluster cluster67_haineux.txt
# Cluster cluster68_haineux.txt
# Cluster cluster69_haineux.txt
# Cluster cluster6_normal.txt
# Cluster cluster71_haineux.txt
# Cluster cluster72_haineux.txt
# Cluster cluster73_haineux.txt
# Cluster cluster77_haineux.txt
# Cluster cluster78_haineux.txt
# Cluster cluster79_haineux.txt
# Cluster cluster7_normal.txt
# Cluster cluster84_haineux.txt
# Cluster cluster86_haineux.txt
# Cluster cluster87_haineux.txt
# Cluster cluster88_haineux.txt
# Cluster cluster89_haineux.txt
# Cluster cluster8_haineux.txt
# Cluster cluster92_normal.txt
# Cluster cluster95_haineux.txt
# Cluster cluster96_haineux.txt
# Cluster cluster97_haineux.txt
# Cluster cluster98_haineux.txt
# Cluster cluster99_haineux.txt
# Dataset miso.
# Cluster cluster0_haineux.txt
# Cluster cluster10_haineux.txt
# Cluster cluster11_haineux.txt
# Cluster cluster12_haineux.txt
# Cluster cluster13_haineux.txt
# Cluster cluster1_haineux.txt
# Cluster cluster20_haineux.txt
# Cluster cluster21_haineux.txt
# Cluster cluster22_haineux.txt
# Cluster cluster24_haineux.txt
# Cluster cluster29_haineux.txt
# Cluster cluster2_haineux.txt
# Cluster cluster31_haineux.txt
# Cluster cluster32_haineux.txt
# Cluster cluster38_haineux.txt
# Cluster cluster40_haineux.txt
# Cluster cluster42_haineux.txt
# Cluster cluster43_haineux.txt
# Cluster cluster44_haineux.txt
# Cluster cluster45_haineux.txt
# Cluster cluster46_haineux.txt
# Cluster cluster47_haineux.txt
# Cluster cluster48_haineux.txt
# Cluster cluster49_haineux.txt
# Cluster cluster50_haineux.txt
# Cluster cluster53_haineux.txt
# Cluster cluster54_haineux.txt
# Cluster cluster55_haineux.txt
# Cluster cluster58_haineux.txt
# Cluster cluster59_haineux.txt
# Cluster cluster62_haineux.txt
# Cluster cluster63_haineux.txt
# Cluster cluster64_haineux.txt
# Cluster cluster65_haineux.txt
# Cluster cluster67_haineux.txt
# Cluster cluster68_haineux.txt
# Cluster cluster69_haineux.txt
# Cluster cluster6_normal.txt
# Cluster cluster70_haineux.txt
# Cluster cluster71_haineux.txt
# Cluster cluster72_haineux.txt
# Cluster cluster73_haineux.txt
# Cluster cluster74_haineux.txt
# Cluster cluster75_haineux.txt
# Cluster cluster76_haineux.txt
# Cluster cluster79_haineux.txt
# Cluster cluster80_haineux.txt
# Cluster cluster82_normal.txt
# Cluster cluster83_haineux.txt
# Cluster cluster84_haineux.txt
# Cluster cluster85_haineux.txt
# Cluster cluster86_haineux.txt
# Cluster cluster88_haineux.txt
# Cluster cluster8_normal.txt
# Cluster cluster90_haineux.txt
# Cluster cluster91_haineux.txt
# Cluster cluster92_haineux.txt
# Cluster cluster93_haineux.txt
# Cluster cluster94_normal.txt
# Cluster cluster95_haineux.txt
# Cluster cluster96_haineux.txt
# Cluster cluster97_haineux.txt
# Cluster cluster98_haineux.txt
# Cluster cluster99_haineux.txt
# Cluster cluster39_haineux.txt
# Cluster cluster61_haineux.txt
# Cluster cluster78_haineux.txt
# Dataset musulman.
# Cluster cluster46_normal.txt
# Cluster cluster13_normal.txt
# Cluster cluster14_normal.txt
# Cluster cluster16_normal.txt
# Cluster cluster1_normal.txt
# Cluster cluster21_normal.txt
# Cluster cluster22_normal.txt
# Cluster cluster24_normal.txt
# Cluster cluster25_normal.txt
# Cluster cluster26_normal.txt
# Cluster cluster27_normal.txt
# Cluster cluster29_normal.txt
# Cluster cluster33_normal.txt
# Cluster cluster34_normal.txt
# Cluster cluster36_haineux.txt
# Cluster cluster3_normal.txt
# Cluster cluster47_normal.txt
# Cluster cluster49_normal.txt
# Cluster cluster4_normal.txt
# Cluster cluster51_normal.txt
# Cluster cluster53_normal.txt
# Cluster cluster60_normal.txt
# Cluster cluster61_haineux.txt
# Cluster cluster67_haineux.txt
# Cluster cluster6_normal.txt
# Cluster cluster73_normal.txt
# Cluster cluster79_haineux.txt
# Cluster cluster7_normal.txt
# Cluster cluster87_haineux.txt
# Cluster cluster88_haineux.txt
# Cluster cluster89_normal.txt
# Cluster cluster95_haineux.txt
# CPU times: user 6min 59s, sys: 24.3 s, total: 7min 23s
# Wall time: 6min 52s
