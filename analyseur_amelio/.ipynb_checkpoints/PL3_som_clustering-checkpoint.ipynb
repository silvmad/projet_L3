# %%
import torch
from transformers import CamembertTokenizer, CamembertModel, CamembertForSequenceClassification, Trainer, TrainingArguments, AutoModel
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from clustertools import *

# %%
from importlib import reload
import clustertools
reload(clustertools)
from clustertools import *

# %%
#répertoire dans lequel seront stockés les clusters, doit se terminer obligatoirement par /
datasets = ["africain", "antisemite", "arabe", "asie", "capacitiste", "chretiens", "gitan", "miso", "musulman"]
cluster_dir = "clusters/{}/"
datasets_dir = "datasets/{}.txt"
# Le transformer n'a besoin que des messages bruts, pas besoin de prétraitement, celui-ci sera 
# effectué par le tokenizer
#raw_dataset_file = "datasets/haine2022_oversampling_myso.txt"

# %% [markdown]
# ### Récupération des tweets

# %%
def load_msg(raw_dataset_file):
    with open(raw_dataset_file, "r") as file:
        raw_dataset = file.read().splitlines()
    return raw_dataset

# %% [markdown]
# ### Création des échantillons
# Ne pas exécuter pour travailler avec toutes les données

# %%
import random
sample_size = 5000

idx_list = random.sample(range(len(raw_dataset)), sample_size)
#clean_dataset = [clean_dataset[i] for i in idx_list]
raw_dataset = [raw_dataset[i] for i in idx_list]

# %% [markdown]
# ### Encodage du jeu de données
#
# On charge le modèle depuis le disque

# %%
model_dir = "models/tweetbert"
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
tokenizer = CamembertTokenizer.from_pretrained(model_dir, do_lowercase=False)
camembert = CamembertModel.from_pretrained(model_dir)
# Out:
# Some weights of the model checkpoint at models/tweetbert were not used when initializing CamembertModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing CamembertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CamembertModel were not initialized from the model checkpoint at models/tweetbert and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
r = camembert.to(device)

# %%
def encode(sample):
    encoded = []
    for n in range(0, len(sample), 50):
        batch = tokenizer(sample[n:n+50], padding=True, truncation=True, max_length=512, return_tensors="pt")
        torch.cuda.empty_cache()
        batch.to(device)
        with torch.no_grad():
            outp = camembert(**batch)
        encoded.append(outp['last_hidden_state'][:,0,:].to('cpu'))
    return torch.cat(encoded)

# %%
#%%time
#dataset_encoded = encode(raw_dataset)
# Out:
# CPU times: user 1min 38s, sys: 1.38 s, total: 1min 39s
# Wall time: 1min 40s

# %% [markdown]
# ### Visualisation du dataset
#
# - On réalise une réduction de dimension afin de visualiser les données dans une grille en deux dimensions
# - On utilise pour cela la méthode PCA

# %%
# %%time

pca = PCA(n_components=2)

#On crée une version en deux dimensions de notre jeu de données
two_dim_dataset = pca.fit_transform(dataset_encoded)
# Out:
# CPU times: user 2.38 s, sys: 2.75 s, total: 5.13 s
# Wall time: 779 ms

# %%
#On utilise la matrice transposée de notre jeu de données pour pouvoir visualiser les données
b = two_dim_dataset.T

# %%
init_globals([msg.split() for msg in raw_dataset], raw_dataset, two_dim_dataset, cluster_dir)

# %%
#Affichage des données
plt.plot(b[0], b[1], 'r.')
plt.show()

# %% [markdown]
# ### SOM

# %%
from minisom import MiniSom

# %%
m = 7
n = 7
som = MiniSom(m, n, 768, neighborhood_function='gaussian', random_seed=0)
som.pca_weights_init(dataset_encoded)

# %%
# %%time
som.train(dataset_encoded, 100000, verbose=True)
# Out:
#  [ 100000 / 100000 ] 100% - 0:00:00 left
#  quantization error: 1.934175638010003
# CPU times: user 44.8 s, sys: 2.68 s, total: 47.5 s
# Wall time: 40.7 s

# %%
# %%time
pred = []
for msg in dataset_encoded:
    winner = som.winner(msg)
    pred.append(winner[0]*n+winner[1])
# Out:
# CPU times: user 1.11 s, sys: 0 ns, total: 1.11 s
# Wall time: 1.11 s

# %% [markdown]
# ### Analyse et sauvegarde des résultats

# %%
res, wlists, mlists, cmlists, e2dmlists, mfw, hkw, clust_n_msg = parse(pred)

# %%
classifier = CamembertForSequenceClassification.from_pretrained("models/tweetbert_val")
#torch.cuda.empty_cache()
r = classifier.to(device)

# %%
def predict(sample):
    pred = []
    for n in range(0, len(sample), 10):
        phrases = sample[n:n+10]
        enc = tokenizer(phrases, padding=True, truncation=True, max_length=512, return_tensors='pt')
        enc.to('cuda:0')
        with torch.no_grad():
            outp = classifier(**enc)
        p = torch.nn.functional.softmax(outp.logits, dim=1)
        labels = torch.argmax(p, dim=1)
        pred.append(labels)
    return torch.cat(pred)

# %%
# %%time 
hate_pred = []
for mlist in mlists:
    hate_pred.append(predict(mlist))
# Out:
# CPU times: user 1min, sys: 0 ns, total: 1min
# Wall time: 1min

# %%
hper = []
for i, p in enumerate(hate_pred):
    bc = torch.bincount(p, minlength=2)
    perc = (bc[1] / (bc[0]+bc[1])).item() * 100
    hper.append(perc)

# %%
print_clusters_info(clust_n_msg, mfw, hkw, hper)
# Out:
# Cluster 0 : 123 messages
# 90 messages contiennent un mot-clé haineux (soit 73.17%)
# 91.06% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : connasse grosse va Quelle petasse grognasse sale Sale poulette Cette La gueule Connasse ! toi Moi Grosse Merci poufiasse oui
#
#
# Cluster 1 : 115 messages
# 91 messages contiennent un mot-clé haineux (soit 79.13%)
# 94.78% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : connasse petasse La grosse poufiasse Cette C poulette sale pétasse Pute oh ma Tu Quelle ! c biatch MDRR guenon
#
#
# Cluster 2 : 268 messages
# 227 messages contiennent un mot-clé haineux (soit 84.70%)
# 89.55% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : t’es toi sale ton va moi te grosse petasse connasse poulette Tu T’es mère si au fais même bien bitch
#
#
# Cluster 3 : 328 messages
# 273 messages contiennent un mot-clé haineux (soit 83.23%)
# 59.15% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : grosse fait pute, me juste si ton quand te t'es être avec même vie suis t’es plus connasse faut toi
#
#
# Cluster 4 : 222 messages
# 190 messages contiennent un mot-clé haineux (soit 85.59%)
# 85.59% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : connasse mère te avec plus grosse ! toi Je grognasse moi va au ton sale se suis fait Et tout
#
#
# Cluster 5 : 104 messages
# 54 messages contiennent un mot-clé haineux (soit 51.92%)
# 15.38% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : poulette ma bonne ! toi 😘 Bonne soirée Merci journée bitch Je mon aussi anniversaire De bon va avec -
#
#
# Cluster 6 : 285 messages
# 256 messages contiennent un mot-clé haineux (soit 89.82%)
# 95.44% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : club grosse sale mère va avec match si nous sa fait équipe contre même ils DE au ont j’ai bien
#
#
# Cluster 7 : 167 messages
# 136 messages contiennent un mot-clé haineux (soit 81.44%)
# 93.41% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : connasse petasse grosse grognasse sale va quelle oui Oh Pleure Une Quelle T'es vraiment pétasse La poulette Je quel Crève
#
#
# Cluster 8 : 193 messages
# 157 messages contiennent un mot-clé haineux (soit 81.35%)
# 92.23% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : ! connasse La va bande petasse poufiasse Oh mon fait Bande !!! C'est bien Je grosse Ça foutre te mère
#
#
# Cluster 9 : 301 messages
# 256 messages contiennent un mot-clé haineux (soit 85.05%)
# 76.41% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : connasse grosse plus sa me petasse se Mais bien suis ! lui Je Il fait mère quoi si sale vraiment
#
#
# Cluster 10 : 205 messages
# 188 messages contiennent un mot-clé haineux (soit 91.71%)
# 83.41% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : grosse suis Je me si plus ou moi Les sale gens tweet sa mon fait petasse réseau va trop au
#
#
# Cluster 11 : 291 messages
# 252 messages contiennent un mot-clé haineux (soit 86.60%)
# 93.47% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : toi sale grosse petasse te sa mère ma si Tu va t'es plus bien me ton t fait c ou
#
#
# Cluster 12 : 221 messages
# 208 messages contiennent un mot-clé haineux (soit 94.12%)
# 99.55% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : mère sale Ta va gros gueule toi te Fils Un grand grosse mere aussi tes Caleta DE sa avec merde
#
#
# Cluster 13 : 134 messages
# 119 messages contiennent un mot-clé haineux (soit 88.81%)
# 95.52% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : c sale sa ton mere mère moi compte grosse te t gros ou mon ma sal toi si me C
#
#
# Cluster 14 : 339 messages
# 299 messages contiennent un mot-clé haineux (soit 88.20%)
# 96.46% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : sale grosse te connasse Tu me toi ton t’es Je grognasse va petasse mère quoi moi merde Mais quand ma
#
#
# Cluster 15 : 304 messages
# 265 messages contiennent un mot-clé haineux (soit 87.17%)
# 99.34% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : mère sale DE Mais PUTE va grosse gros nique FILS toi grand te Sale bande tes Nique TA Ta lui
#
#
# Cluster 16 : 148 messages
# 126 messages contiennent un mot-clé haineux (soit 85.14%)
# 74.32% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : si ma suis j’ai grosse mère connasse petasse me mes plus vais sa bitch j'ai bien moi va fait son
#
#
# Cluster 17 : 196 messages
# 170 messages contiennent un mot-clé haineux (soit 86.73%)
# 92.86% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : t’es toi sale grosse mère plus petasse j’ai ma grognasse meuf « » mon sa c ton t me ou
#
#
# Cluster 18 : 291 messages
# 254 messages contiennent un mot-clé haineux (soit 87.29%)
# 86.60% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : connasse Elle grognasse petasse grosse ma c suis me sa là fait avec même bitch son au va quoi Je
#
#
# Cluster 19 : 446 messages
# 377 messages contiennent un mot-clé haineux (soit 84.53%)
# 76.46% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : plus connasse fait suis Je j'ai grosse avec sa me guenon au se Il Le bitch si ou petasse moi
#
#
# Cluster 20 : 168 messages
# 128 messages contiennent un mot-clé haineux (soit 76.19%)
# 75.60% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : sa petasse bitch c connasse suis va oh son Je + mère trop fait grosse alors me bitch. lui Bitch
#
#
# Cluster 21 : 123 messages
# 1 messages contiennent un mot-clé haineux (soit 0.81%)
# 84.55% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : DE PUTE LA FILS A JE TA SALOPE SALE ET CETTE UNE TU MAIS MÈRE LE SUIS MOI LES PAS
#
#
# Cluster 22 : 174 messages
# 133 messages contiennent un mot-clé haineux (soit 76.44%)
# 75.29% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : bonne ! Il Macron Ruffin fait par son soit lui La blondasse au pute, sa parle » Mélenchon femme dit
#
#
# Cluster 23 : 84 messages
# 53 messages contiennent un mot-clé haineux (soit 63.10%)
# 46.43% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : suis Je ma me j’ai bonne là journée petasse au mon connasse pétasse plus Bonne mes si grosse pute. par
#
#
# Cluster 24 : 319 messages
# 263 messages contiennent un mot-clé haineux (soit 82.45%)
# 67.08% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : j’ai connasse petasse grosse « » ma fait c trop me si suis bitch moi sa m’a avec bien qu’elle
#
#
# Cluster 25 : 106 messages
# 98 messages contiennent un mot-clé haineux (soit 92.45%)
# 88.68% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : plus sa qu’il avec fait là même mère va c ma Le sale dire j'ai merde 2 vraiment quand t'es
#
#
# Cluster 26 : 157 messages
# 131 messages contiennent un mot-clé haineux (soit 83.44%)
# 86.62% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : ! Et connasse La sa avec blondasse fait votre !!! gueule bien ... se guenon par va Macron ou France
#
#
# Cluster 27 : 117 messages
# 78 messages contiennent un mot-clé haineux (soit 66.67%)
# 65.81% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : ! avec plus bobonne bonne blondasse tout La C'est sa encore par connasse , l son y Il bien 1
#
#
# Cluster 28 : 257 messages
# 200 messages contiennent un mot-clé haineux (soit 77.82%)
# 50.19% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : se fait au ! avec bien même sa plus bonne par me tout si Je dire toi juste te y
#
#
# Cluster 29 : 396 messages
# 233 messages contiennent un mot-clé haineux (soit 58.84%)
# 22.73% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : bonne « se plus ou femme au avec si fait bien par même » son sont Et ! dit suis
#
#
# Cluster 30 : 121 messages
# 107 messages contiennent un mot-clé haineux (soit 88.43%)
# 90.91% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : #TPMP #tpmp connasse blondasse Delphine ! sa Elle fait bien Une se va Quelle plus c delormeau son C'est C’est
#
#
# Cluster 31 : 234 messages
# 175 messages contiennent un mot-clé haineux (soit 74.79%)
# 64.53% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : avec me DE se bien fait te plus sa même toi quand bonne trop si ma t’es Mais merde vraiment
#
#
# Cluster 32 : 121 messages
# 103 messages contiennent un mot-clé haineux (soit 85.12%)
# 85.95% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : « blanche » raciste sale c fait peut ou être connasse arabe femme racisme alors mal Je dire plus Mais
#
#
# Cluster 33 : 379 messages
# 329 messages contiennent un mot-clé haineux (soit 86.81%)
# 56.46% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : ?" avec , me pute, bien se suis connasse ""pute fait plus grosse j'ai ma mère son toi te dit
#
#
# Cluster 34 : 239 messages
# 190 messages contiennent un mot-clé haineux (soit 79.50%)
# 64.85% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : « » j’ai bitch C’est connasse suis J’ai si ma t’es sa me meuf moi petasse quand avec bonne dit
#
#
# Cluster 35 : 567 messages
# 403 messages contiennent un mot-clé haineux (soit 71.08%)
# 44.80% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : fait avec se bonne ou plus au son par sont ! si même tout bien me ""pute « sa blanche
#
#
# Cluster 36 : 368 messages
# 267 messages contiennent un mot-clé haineux (soit 72.55%)
# 50.54% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : plus « toi avec sa bonne me j’ai » au tout se ! te ou fait même quand t’es si
#
#
# Cluster 37 : 103 messages
# 103 messages contiennent un mot-clé haineux (soit 100.00%)
# 0.00% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : Très dangereux boire bb l’horizontale complète/!\ nourrir faut se lever porter qu’il soit peu incliné grognasse père pourra 50/50 préparant
#
#
# Cluster 38 : 38 messages
# 26 messages contiennent un mot-clé haineux (soit 68.42%)
# 55.26% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : plus bonne me avec t suis j'ai c si se dm donc au d pendant dire ou lui - connasse
#
#
# Cluster 39 : 180 messages
# 157 messages contiennent un mot-clé haineux (soit 87.22%)
# 94.44% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : sale sa c va mon mère grosse bitch quand bien toi moi avec par hein fait ma me au trop
#
#
# Cluster 40 : 168 messages
# 126 messages contiennent un mot-clé haineux (soit 75.00%)
# 58.93% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : blanche"" ""pute avec suis si , ?" dit son te "" t'es gros bien quand pute"" C'est """ moi "Le
#
#
# Cluster 41 : 104 messages
# 58 messages contiennent un mot-clé haineux (soit 55.77%)
# 76.92% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : car Caleta mère t bitch Connasse A toi t’es DE CHERH grosse bad grand ma poulette tous petasse c *
#
#
# Cluster 42 : 33 messages
# 32 messages contiennent un mot-clé haineux (soit 96.97%)
# 0.00% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : « 🗞FLASH- Elon Musk répond condamnation La Fédération internationale journalistes. Par ces mots I don’t give fuck…bitch ». Dixit jm’en
#
#
# Cluster 43 : 420 messages
# 317 messages contiennent un mot-clé haineux (soit 75.48%)
# 31.90% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : me mon te avec plus fait au ma si moi tout son même se j'ai lui va bonne toi ton
#
#
# Cluster 44 : 198 messages
# 96 messages contiennent un mot-clé haineux (soit 48.48%)
# 13.13% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : bonne plus , te avec se au bien me sont tout ! même fait si ou nous très ton va
#
#
# Cluster 45 : 276 messages
# 208 messages contiennent un mot-clé haineux (soit 75.36%)
# 40.58% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : avec sa fait tout se plus quand me dit te bonne son au ou lui même , : ! sont
#
#
# Cluster 46 : 101 messages
# 0 messages contiennent un mot-clé haineux (soit 0.00%)
# 0.00% de messages sont détectés comme haineux par le modèle
# Les 5 mots les plus fréquents : &gt;$.£]*]*\ MAIS COMMENT ÇA GROGNASSE
#
#
# Cluster 47 : 101 messages
# 68 messages contiennent un mot-clé haineux (soit 67.33%)
# 93.07% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : grosse sale pétasse Pute poufiasse baisée CONNASSE perre petasse ! grognasse mal tg connasse gueule pleure PUTE ... content NoRt
#
#
# Cluster 48 : 170 messages
# 144 messages contiennent un mot-clé haineux (soit 84.71%)
# 90.00% de messages sont détectés comme haineux par le modèle
# Les 20 mots les plus fréquents : sale t’es grosse toi petasse ma va grognasse connasse t te ton gueule c ferme me dis ! t’as non

# %%
plot_results(pred, two_dim_dataset)

# %%
method = "miso_bertsom" + str(n*m)
save_clusters_msg(cmlists, mlists, e2dmlists, method)
save_clusters_info(clust_n_msg, mfw, hkw, method, hper)

# %% [markdown]
# ### Sauvegarder le modèle et les poids

# %%
import pickle

dir = cluster_dir + method + "/"

# %%
with open(dir + 'som.p', 'wb') as outfile:
    pickle.dump(som, outfile)
    
np.save(dir + "som_weights.npy" ,som.get_weights())

# %% [markdown]
# ### Sauvegarder les clusters encodés

# %%
emlists = []
for i in sorted(res):
    emlist = []
    for idx in res[i]:
        emlist.append(np.array(dataset_encoded[idx]))
    emlists.append(np.array(emlist))

# %%
for i, emlist in enumerate(emlists):
    np.save(dir + method + "_cluster_{}_encoded.npy".format(i), emlist)

# %%
for dataset in datasets:
    print("Travail sur le dataset {}.".format(dataset))
    print("Chargement des messages.")
    raw_dataset = load_msg(datasets_dir.format(dataset))
    print("Encodage.")
    dataset_encoded = encode(raw_dataset)
    m = 10
    n = 10
    print("Partitionnement.")
    som = MiniSom(m, n, 768, neighborhood_function='gaussian', random_seed=0)
    som.pca_weights_init(dataset_encoded)
    som.train(dataset_encoded, 100000, verbose=True)
    pred = []
    for msg in dataset_encoded:
        winner = som.winner(msg)
        pred.append(winner[0]*n+winner[1])
    res, wlists, mlists, cmlists, e2dmlists, mfw, hkw, clust_n_msg = parse(pred)
    print("Évaluation des résultats.")
    hate_pred = []
    for mlist in mlists:
        hate_pred.append(predict(mlist))
    hper = []
    for i, p in enumerate(hate_pred):
        bc = torch.bincount(p, minlength=2)
        perc = (bc[1] / (bc[0]+bc[1])).item() * 100
        hper.append(perc)
    cd = cluster_dir.format(dataset)
    if not os.path.exists(cd): 
        os.mkdir(cluster_dir_ct)
    print("Sauvegarde des résultats.")
    for i in range(100):
        if hper[i] >= 80 or hper[i] <= 20:
            lab = "haineux" if hper[i] >= 80 else "normal"
            save_cluster_info(cd + "info.txt", clust_n_msg[i], mfw[i], hkw[i], hper[i], None)
            save_cluster_raw_msg(mlists[i], cd + "cluster{}_{}.txt".format(i, lab))
    print()
